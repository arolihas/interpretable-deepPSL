# %% [markdown]
# # Training model from https://github.com/ThanhTunggggg/DeepLoc.git
#
# Later I will replace the last layer (FC) with attention or add attention before the FC layer.

# %%
# %cd 'drive/My Drive/GaTech/Fall20/DLT-CSE_8803/Project/interpretable_deepPSL/lstm_attn/lstm_linear_model'
# Out:
# /content/drive/My Drive/GaTech/Fall20/DLT-CSE_8803/Project/interpretable_deepPSL/lstm_attn/lstm_linear_model

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 2.3MB 10.6MB/s
# ...
#      |████████████████████████████████| 92kB 7.2MB/s
# ...

# %%
# !pip list | grep torch
# Out:
# pytorch-nlp                   0.5.0
# torch                         1.7.0+cu101
# torchsummary                  1.5.1
# torchtext                     0.3.1
# torchvision                   0.8.1+cu101

# %%
# Training using the best hyperparameters learned using grid search below
# !python train.py --data_dir data --model_dir experiments/attention/ --restore_file attn512_lr0.01_drop0_20epochs
# Note this was done running for 100 additional epochs (logs are stored in train.log)
# Out:
# Traceback (most recent call last):
#   File "train.py", line 8, in <module>
#     import torch
#   File "/usr/local/lib/python3.6/dist-packages/torch/__init__.py", line 190, in <module>
#     from torch._C import *
# RuntimeError: KeyboardInterrupt:

# %%
# !pip list | grep pickle
# !python evaluate.py --data_dir data --model_dir experiments/attention \
    --visualize --restore_file attn512_lr0.01_drop0_20epochs
# Out:
# Creating the dataset...
# - done.
# Starting evaluation
# loading experiments/attention/attn512_lr0.01_drop0_20epochs.pth
# DONE

# %%
# Training using same hyperparams but with uniform attention weights
# !python train.py --data_dir data --model_dir experiments/attention_average
# Out:
# Loading the datasets...
# - done.
# batch_size_50-LR_0.01-Drop_0.0-Attn_512
# Starting training for 120 epoch(s)
# Epoch 1/120
# 100% 196/196 [00:48<00:00,  4.04it/s, loss=33.538]
# - Train metrics: accuracy: 0.080 ; loss: 70.187
# - Eval metrics : accuracy: 0.227 ; loss: 2.958
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 2/120
# 100% 196/196 [00:48<00:00,  4.04it/s, loss=2.854]
# - Train metrics: accuracy: 0.320 ; loss: 1.967
# - Eval metrics : accuracy: 0.298 ; loss: 2.246
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 3/120
# 100% 196/196 [00:48<00:00,  4.05it/s, loss=2.330]
# - Train metrics: accuracy: 0.310 ; loss: 1.833
# - Eval metrics : accuracy: 0.380 ; loss: 1.808
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 4/120
# 100% 196/196 [00:48<00:00,  4.04it/s, loss=2.578]
# - Train metrics: accuracy: 0.290 ; loss: 1.833
# - Eval metrics : accuracy: 0.373 ; loss: 1.741
# Checkpoint Directory exists!
# Epoch 5/120
# ...

# %%
# !python search_hyperparams.py --data_dir data --parent_dir experiments/attn_lr_drop/
# Out:
# /usr/bin/python3 train.py --model_dir=experiments/attn_lr_drop/attn_size_32-lr_0.001-drop_0.0 --data_dir data
# Loading the datasets...
# - done.
# batch_size_100-LR_0.001-Drop_0.0-Attn_32
# Starting training for 20 epoch(s)
# Epoch 1/20
# 100% 98/98 [00:40<00:00,  2.44it/s, loss=2.001]
# - Train metrics: accuracy: 0.030 ; loss: 2.318
# - Eval metrics : accuracy: 0.275 ; loss: 1.952
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 2/20
# 100% 98/98 [00:39<00:00,  2.50it/s, loss=1.917]
# - Train metrics: accuracy: 0.230 ; loss: 1.952
# - Eval metrics : accuracy: 0.328 ; loss: 1.900
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 3/20
# 100% 98/98 [00:38<00:00,  2.55it/s, loss=1.864]
# - Train metrics: accuracy: 0.290 ; loss: 1.881
# - Eval metrics : accuracy: 0.344 ; loss: 1.868
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 4/20
# 100% 98/98 [00:37<00:00,  2.59it/s, loss=1.863]
# - Train metrics: accuracy: 0.310 ; loss: 1.862
# ...

# %%
# !python search_hyperparams.py --data_dir data --parent_dir experiments/attn_lr_drop/
# Out:
# /usr/bin/python3 train.py --model_dir=experiments/attn_lr_drop/attn_size_512-lr_0.001-drop_0.0 --data_dir data
# Loading the datasets...
# - done.
# batch_size_50-LR_0.001-Drop_0.0-Attn_512
# Starting training for 20 epoch(s)
# Epoch 1/20
# 100% 196/196 [00:56<00:00,  3.49it/s, loss=1.963]
# - Train metrics: accuracy: 0.150 ; loss: 2.139
# - Eval metrics : accuracy: 0.318 ; loss: 1.937
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 2/20
# 100% 196/196 [00:55<00:00,  3.50it/s, loss=1.862]
# - Train metrics: accuracy: 0.250 ; loss: 1.883
# - Eval metrics : accuracy: 0.360 ; loss: 1.857
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 3/20
# 100% 196/196 [00:55<00:00,  3.53it/s, loss=1.790]
# - Train metrics: accuracy: 0.320 ; loss: 1.821
# - Eval metrics : accuracy: 0.377 ; loss: 1.803
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 4/20
# 100% 196/196 [00:56<00:00,  3.49it/s, loss=1.733]
# ...

# %%
# !python search_hyperparams.py --data_dir data --parent_dir experiments/attn_lr_drop/
# Out:
# /usr/bin/python3 train.py --model_dir=experiments/attn_lr_drop/attn_size_2048-lr_0.001-drop_0.0 --data_dir data
# Loading the datasets...
# - done.
# batch_size_25-LR_0.001-Drop_0.0-Attn_2048
# Starting training for 20 epoch(s)
# Epoch 1/20
# 100% 392/392 [01:31<00:00,  4.30it/s, loss=1.915]
# - Train metrics: accuracy: 0.260 ; loss: 2.022
# - Eval metrics : accuracy: 0.338 ; loss: 1.853
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 2/20
# 100% 392/392 [01:31<00:00,  4.27it/s, loss=1.752]
# - Train metrics: accuracy: 0.360 ; loss: 1.828
# - Eval metrics : accuracy: 0.330 ; loss: 1.951
# Checkpoint Directory exists!
# Epoch 3/20
# 100% 392/392 [01:30<00:00,  4.32it/s, loss=1.775]
# - Train metrics: accuracy: 0.360 ; loss: 1.878
# - Eval metrics : accuracy: 0.390 ; loss: 1.737
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 4/20
# 100% 392/392 [01:30<00:00,  4.33it/s, loss=1.727]
# - Train metrics: accuracy: 0.340 ; loss: 1.774
# ...

# %%
# !python search_hyperparams.py --data_dir data --parent_dir experiments/attn_lr_drop/
# Out:
# /usr/bin/python3 train.py --model_dir=experiments/attn_lr_drop/attn_size_32-lr_0.01-drop_0.0 --data_dir data
# Loading the datasets...
# - done.
# batch_size_25-LR_0.01-Drop_0.0-Attn_32
# Starting training for 20 epoch(s)
# Epoch 1/20
# 100% 392/392 [01:33<00:00,  4.18it/s, loss=1.778]
# - Train metrics: accuracy: 0.260 ; loss: 1.981
# - Eval metrics : accuracy: 0.435 ; loss: 1.554
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 2/20
# 100% 392/392 [01:31<00:00,  4.30it/s, loss=1.510]
# - Train metrics: accuracy: 0.430 ; loss: 1.520
# - Eval metrics : accuracy: 0.439 ; loss: 1.542
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 3/20
# 100% 392/392 [01:31<00:00,  4.26it/s, loss=1.431]
# - Train metrics: accuracy: 0.450 ; loss: 1.444
# - Eval metrics : accuracy: 0.479 ; loss: 1.442
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 4/20
# 100% 392/392 [01:32<00:00,  4.25it/s, loss=1.346]
# ...

# %%
# !python search_hyperparams.py --data_dir data --parent_dir experiments/attn_lr_drop/
# Out:
# /usr/bin/python3 train.py --model_dir=experiments/attn_lr_drop/attn_size_64-lr_0.01-drop_0.0 --data_dir data
# Loading the datasets...
# - done.
# batch_size_100-LR_0.01-Drop_0.0-Attn_64
# Starting training for 20 epoch(s)
# Epoch 1/20
# 100% 98/98 [01:16<00:00,  1.28it/s, loss=1.944]
# - Train metrics: accuracy: 0.030 ; loss: 2.318
# - Eval metrics : accuracy: 0.309 ; loss: 1.942
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 2/20
# 100% 98/98 [01:16<00:00,  1.28it/s, loss=1.800]
# - Train metrics: accuracy: 0.310 ; loss: 1.892
# - Eval metrics : accuracy: 0.406 ; loss: 1.714
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 3/20
# 100% 98/98 [01:17<00:00,  1.27it/s, loss=1.651]
# - Train metrics: accuracy: 0.350 ; loss: 1.883
# - Eval metrics : accuracy: 0.404 ; loss: 1.678
# Checkpoint Directory exists!
# Epoch 4/20
# 100% 98/98 [01:16<00:00,  1.28it/s, loss=1.624]
# - Train metrics: accuracy: 0.380 ; loss: 1.785
# ...

# %%
# !python search_hyperparams.py --data_dir data --parent_dir experiments/attn_lr_drop/
# Out:
# /usr/bin/python3 train.py --model_dir=experiments/attn_lr_drop/attn_size_1024-lr_0.01-drop_0.0 --data_dir data
# Loading the datasets...
# - done.
# batch_size_25-LR_0.01-Drop_0.0-Attn_1024
# Starting training for 20 epoch(s)
# Epoch 1/20
# 100% 392/392 [01:34<00:00,  4.16it/s, loss=1.778]
# - Train metrics: accuracy: 0.260 ; loss: 1.981
# - Eval metrics : accuracy: 0.435 ; loss: 1.554
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 2/20
# 100% 392/392 [01:30<00:00,  4.33it/s, loss=1.510]
# - Train metrics: accuracy: 0.430 ; loss: 1.520
# - Eval metrics : accuracy: 0.439 ; loss: 1.542
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 3/20
# 100% 392/392 [01:28<00:00,  4.42it/s, loss=1.431]
# - Train metrics: accuracy: 0.450 ; loss: 1.444
# - Eval metrics : accuracy: 0.479 ; loss: 1.442
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 4/20
# 100% 392/392 [01:27<00:00,  4.48it/s, loss=1.346]
# ...

# %%
# !python search_hyperparams.py --data_dir data --parent_dir experiments/attn_lr_drop/
# Out:
# /usr/bin/python3 train.py --model_dir=experiments/attn_lr_drop/attn_size_32-lr_0.1-drop_0.2 --data_dir data
# Loading the datasets...
# - done.
# batch_size_100-LR_0.1-Drop_0.2-Attn_32
# Starting training for 20 epoch(s)
# Epoch 1/20
# 100% 98/98 [00:47<00:00,  2.07it/s, loss=1.985]
# - Train metrics: accuracy: 0.030 ; loss: 2.319
# - Eval metrics : accuracy: 0.256 ; loss: 1.985
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 2/20
# 100% 98/98 [00:47<00:00,  2.06it/s, loss=1.958]
# - Train metrics: accuracy: 0.280 ; loss: 1.868
# - Eval metrics : accuracy: 0.307 ; loss: 1.955
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 3/20
# 100% 98/98 [00:47<00:00,  2.07it/s, loss=1.941]
# - Train metrics: accuracy: 0.310 ; loss: 1.950
# - Eval metrics : accuracy: 0.318 ; loss: 1.956
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 4/20
# 100% 98/98 [00:47<00:00,  2.07it/s, loss=1.941]
# - Train metrics: accuracy: 0.270 ; loss: 1.964
# ...

# %%
# !python train.py --data_dir data --model_dir experiments/base_model
