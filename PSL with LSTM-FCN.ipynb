# %% [markdown]
# # Training model from https://github.com/ThanhTunggggg/DeepLoc.git
#
# Later I will replace the last layer (FC) with attention or add attention before the FC layer.

# %%
# %cd 'drive/My Drive/GaTech/Fall20/DLT-CSE_8803/Project/interpretable_deepPSL/lstm_attn/lstm_linear_model'
# Out:
# /content/drive/My Drive/GaTech/Fall20/DLT-CSE_8803/Project/interpretable_deepPSL/lstm_attn/lstm_linear_model

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 2.3MB 4.3MB/s
# ...

# %%
# !python train.py --data_dir data --model_dir experiments/base_model
# Out:
# Loading the datasets...
# - done.
# Starting training for 20 epoch(s)
# Epoch 1/20
# 100% 1960/1960 [05:08<00:00,  6.36it/s, loss=1.684]
# - Train metrics: accuracy: 0.440 ; loss: 1.600
# - Eval metrics : accuracy: 0.490 ; loss: 1.437
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 2/20
# 100% 1960/1960 [04:53<00:00,  6.69it/s, loss=1.405]
# - Train metrics: accuracy: 0.570 ; loss: 1.335
# - Eval metrics : accuracy: 0.526 ; loss: 1.318
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 3/20
# 100% 1960/1960 [04:47<00:00,  6.81it/s, loss=1.310]
# - Train metrics: accuracy: 0.550 ; loss: 1.270
# - Eval metrics : accuracy: 0.557 ; loss: 1.221
# Checkpoint Directory exists!
# - Found new best accuracy
# Epoch 4/20
# 100% 1960/1960 [04:46<00:00,  6.85it/s, loss=1.346]
# - Train metrics: accuracy: 0.550 ; loss: 1.361
# - Eval metrics : accuracy: 0.529 ; loss: 1.285
# Checkpoint Directory exists!
# Epoch 5/20
# ...
