# %% [markdown]
# ## Convolutional LSTM with attention mechanism
# Tutorial on how to train a convolutional neural network with a bidirectional LSTM and attention mechansim to predict protein subcellular localization.

# %%
# Import all the necessary modules
import os
import sys
os.environ["THEANO_FLAGS"] = "mode=FAST_RUN,optimizer=None,device=cpu,floatX=float32"
sys.path.insert(0,'..')
import numpy as np
import theano
import theano.tensor as T
import lasagne
from confusionmatrix import ConfusionMatrix
from utils import iterate_minibatches, LSTMAttentionDecodeFeedbackLayer
import matplotlib.pyplot as plt
import time
import itertools
# %matplotlib inline

# %% [markdown]
# ### Building the network
# The first thing that we have to do is to define the network architecture. Here we are going to use an input layer, two convolutional layers, a bidirectional LSTM, an attention layer, a dense layer and an output layer. These are the steps that we are going to follow:
#
# 1.- Specify the hyperparameters of the network:

# %%
batch_size = 128
seq_len = 1000
n_feat = 20
n_hid = 15
n_class = 10
lr = 0.0025
n_filt = 10
drop_prob = 0.5

# %% [markdown]
# 2.- Define the input variables to our network:

# %%
# We use ftensor3 because the protein data is a 3D-matrix in float32 
input_var = T.ftensor3('inputs')
# ivector because the labels is a single dimensional vector of integers
target_var = T.ivector('targets')
# fmatrix because the masks to ignore the padded positions is a 2D-matrix in float32
mask_var = T.fmatrix('masks')
# Dummy data to check the size of the layers during the building of the network
X = np.random.randint(0,10,size=(batch_size,seq_len,n_feat)).astype('float32')
Xmask = np.ones((batch_size,seq_len)).astype('float32')

# %% [markdown]
# 3.- Define the layers of the network:

# %%
# Input layer, holds the shape of the data
l_in = lasagne.layers.InputLayer(shape=(batch_size, None, n_feat), input_var=input_var, name='Input')
print('Input layer: {}'.format(
    lasagne.layers.get_output(l_in, inputs={l_in: input_var}).eval({input_var: X}).shape))

# Mask input layer
l_mask = lasagne.layers.InputLayer(shape=(batch_size, None), input_var=mask_var, name='Mask')
print('Mask layer: {}'.format(
    lasagne.layers.get_output(l_mask, inputs={l_mask: mask_var}).eval({mask_var: Xmask}).shape))

# Shuffle shape to be properly read by the CNN layer
l_shu = lasagne.layers.DimshuffleLayer(l_in, (0,2,1))
print('DimshuffleLayer layer: {}'.format(
    lasagne.layers.get_output(l_shu, inputs={l_in: input_var}).eval({input_var: X}).shape))

# Convolutional layers with different filter size
l_conv_a = lasagne.layers.Conv1DLayer(l_shu, num_filters=n_filt, pad='same', stride=1, 
                                      filter_size=3, nonlinearity=lasagne.nonlinearities.rectify)
print('Convolutional layer size 3: {}'.format(
    lasagne.layers.get_output(l_conv_a, inputs={l_in: input_var}).eval({input_var: X}).shape))

l_conv_b = lasagne.layers.Conv1DLayer(l_shu, num_filters=n_filt, pad='same', stride=1, 
                                      filter_size=5, nonlinearity=lasagne.nonlinearities.rectify)
print('Convolutional layer size 5: {}'.format(
    lasagne.layers.get_output(l_conv_b, inputs={l_in: input_var}).eval({input_var: X}).shape))

# The output is concatenated
l_conc = lasagne.layers.ConcatLayer([l_conv_a, l_conv_b], axis=1)
print('Concatenated convolutional layers: {}'.format(
    lasagne.layers.get_output(l_conc, inputs={l_in: input_var}).eval({input_var: X}).shape))

# Second CNN layer
l_conv_final = lasagne.layers.Conv1DLayer(l_conc, num_filters=n_filt*2, pad='same', 
                                          stride=1, filter_size=3, 
                                          nonlinearity=lasagne.nonlinearities.rectify)
print('Final convolutional layer: {}'.format(
    lasagne.layers.get_output(l_conv_final, inputs={l_in: input_var}).eval({input_var: X}).shape))

l_reshu = lasagne.layers.DimshuffleLayer(l_conv_final, (0,2,1))
print('Second DimshuffleLayer layer: {}'.format(
    lasagne.layers.get_output(l_reshu, inputs={l_in: input_var}).eval({input_var: X}).shape))

l_fwd = lasagne.layers.LSTMLayer(l_reshu, num_units=n_hid, name='LSTMFwd', mask_input=l_mask,
                                 nonlinearity=lasagne.nonlinearities.tanh)
l_bck = lasagne.layers.LSTMLayer(l_reshu, num_units=n_hid, name='LSTMBck', mask_input=l_mask,
                                 backwards=True, nonlinearity=lasagne.nonlinearities.tanh)
print('Forward LSTM layer: {}'.format(
    lasagne.layers.get_output(l_fwd, inputs={l_in: input_var, l_mask: mask_var}).eval(
        {input_var: X, mask_var:Xmask}).shape))
print('Backward LSTM layer: {}'.format(
    lasagne.layers.get_output(l_bck, inputs={l_in: input_var, l_mask: mask_var}).eval(
        {input_var: X, mask_var:Xmask}).shape))

# Concatenate both layers
l_conc_lstm = lasagne.layers.ConcatLayer([l_fwd, l_bck], axis=2)

print('Concatenated hidden states: {}'.format(
    lasagne.layers.get_output(l_conc_lstm, inputs={l_in: input_var, l_mask: mask_var}).eval(
        {input_var: X, mask_var:Xmask}).shape))

l_att = LSTMAttentionDecodeFeedbackLayer(l_conc_lstm, mask_input=l_mask, 
                                         num_units=n_hid*2, aln_num_units=n_hid, 
                                         n_decodesteps=2, name='LSTMAttention')
print('Attention layer: {}'.format(
    lasagne.layers.get_output(l_att, inputs={l_in: input_var, l_mask: mask_var}).eval(
        {input_var: X, mask_var:Xmask}).shape))

l_last_hid = lasagne.layers.SliceLayer(l_att, indices=-1, axis=1)
print('Last decoding step: {}'.format(
    lasagne.layers.get_output(l_last_hid, inputs={l_in: input_var, l_mask: mask_var}).eval(
        {input_var: X, mask_var:Xmask}).shape))


# Dense layer with ReLu activation function
l_dense = lasagne.layers.DenseLayer(l_last_hid, num_units=n_hid*2, name="Dense",
                                    nonlinearity=lasagne.nonlinearities.rectify)
print('Dense layer: {}'.format(
    lasagne.layers.get_output(l_dense, inputs={l_in: input_var, l_mask: mask_var}).eval(
        {input_var: X, mask_var:Xmask}).shape))

# Output layer with a Softmax activation function. Note that we include a dropout layer
l_out = lasagne.layers.DenseLayer(lasagne.layers.dropout(l_dense, p=drop_prob), num_units=n_class, name="Softmax", 
                                  nonlinearity=lasagne.nonlinearities.softmax)
print('Output layer: {}'.format(
    lasagne.layers.get_output(l_out, inputs={l_in: input_var, l_mask: mask_var}).eval(
        {input_var: X, mask_var:Xmask}).shape))
# Out:
# Input layer: (128, 1000, 20)
# Mask layer: (128, 1000)
# DimshuffleLayer layer: (128, 20, 1000)
# Convolutional layer size 3: (128, 10, 1000)
# Convolutional layer size 5: (128, 10, 1000)
# Concatenated convolutional layers: (128, 20, 1000)
# Final convolutional layer: (128, 20, 1000)
# Second DimshuffleLayer layer: (128, 1000, 20)
# Forward LSTM layer: (128, 1000, 15)
# Backward LSTM layer: (128, 1000, 15)
# Concatenated hidden states: (128, 1000, 30)
# Attention layer: (128, 2, 30)
# Last decoding step: (128, 30)
# Dense layer: (128, 30)
# Output layer: (128, 10)

# %% [markdown]
# 4.- Calculate the prediction and network loss for the training set and update the network weights:

# %%
# Get output training, deterministic=False is used for training
prediction = lasagne.layers.get_output(l_out, inputs={l_in: input_var, l_mask: mask_var}, deterministic=False)

# Calculate the categorical cross entropy between the labels and the prediction
t_loss = T.nnet.categorical_crossentropy(prediction, target_var)

# Training loss
loss = T.mean(t_loss)

# Parameters
params = lasagne.layers.get_all_params([l_out], trainable=True)

# Get the network gradients and perform total norm constraint normalization
all_grads = lasagne.updates.total_norm_constraint(T.grad(loss, params),3)

# Update parameters using ADAM 
updates = lasagne.updates.adam(all_grads, params, learning_rate=lr)

# %% [markdown]
# 5.- Calculate the prediction and network loss for the validation set:

# %%
# Get output validation, deterministic=True is only use for validation
val_prediction = lasagne.layers.get_output(l_out, inputs={l_in: input_var, l_mask: mask_var}, deterministic=True)

# Calculate the categorical cross entropy between the labels and the prediction
t_val_loss = lasagne.objectives.categorical_crossentropy(val_prediction, target_var)

# Validation loss 
val_loss = T.mean(t_val_loss)

# %% [markdown]
# 6.- Build theano functions:

# %%
# Build functions
train_fn = theano.function([input_var, target_var, mask_var], [loss, prediction], updates=updates)
val_fn = theano.function([input_var, target_var, mask_var], [val_loss, val_prediction, l_att.alpha])

# %% [markdown]
# ### Load dataset
# Once that the network is built, the next step is to load the training and the validation set

# %%
# Load the encoded protein sequences, labels and masks
train = np.load('../data/train.npz')
X_train = train['X_train']
y_train = train['y_train']
mask_train = train['mask_train']
print(X_train.shape)
# Out:
# (4763, 1000, 20)

# %%
validation = np.load('../data/test.npz')
X_val = validation['X_test']
y_val = validation['y_test']
mask_val = validation['mask_test']
print(X_val.shape)
# Out:
# (1195, 1000, 20)

# %% [markdown]
# ### Training
# Once that the data is ready and the network compiled we can start with the training of the model.
# Here we define the number of epochs that we want to perform

# %%
# Number of epochs
num_epochs = 120

# Lists to save loss and accuracy of each epoch
loss_training = []
loss_validation = []
acc_training = []
acc_validation = []
start_time = time.time()
min_val_loss = float("inf")

# Start training 
for epoch in range(num_epochs):
    
    # Full pass training set
    train_err = 0
    train_batches = 0
    confusion_train = ConfusionMatrix(n_class)

    # Generate minibatches and train on each one of them
    for batch in iterate_minibatches(X_train.astype(np.float32), y_train.astype(np.int32), 
                                     mask_train.astype(np.float32), batch_size, shuffle=True):
        # Inputs to the network
        inputs, targets, in_masks = batch
        # Calculate loss and prediction
        tr_err, predict = train_fn(inputs, targets, in_masks)
        train_err += tr_err
        train_batches += 1
        # Get the predicted class, the one with the maximum likelihood
        preds = np.argmax(predict, axis=-1)
        confusion_train.batch_add(targets, preds)
    
    # Average loss and accuracy
    train_loss = train_err / train_batches
    train_accuracy = confusion_train.accuracy()
    cf_train = confusion_train.ret_mat()

    val_err = 0
    val_batches = 0
    confusion_valid = ConfusionMatrix(n_class)
    
    # Generate minibatches and validate on each one of them, same procedure as before
    for batch in iterate_minibatches(X_val.astype(np.float32), y_val.astype(np.int32), 
                                     mask_val.astype(np.float32), batch_size, shuffle=True):
        inputs, targets, in_masks = batch
        err, predict_val, alphas = val_fn(inputs, targets, in_masks)
        val_err += err
        val_batches += 1
        preds = np.argmax(predict_val, axis=-1)
        confusion_valid.batch_add(targets, preds)

    val_loss = val_err / val_batches
    val_accuracy = confusion_valid.accuracy()
    cf_val = confusion_valid.ret_mat()
    
    loss_training.append(train_loss)
    loss_validation.append(val_loss)
    acc_training.append(train_accuracy)
    acc_validation.append(val_accuracy)
    
    # Save the model parameters at the epoch with the lowest validation loss
    if min_val_loss > val_loss:
        min_val_loss = val_loss
        np.savez('params/CNN-LSTM-Attention_params.npz', *lasagne.layers.get_all_param_values(l_out))
    
    print("Epoch {} of {} time elapsed {:.3f}s".format(epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss:\t\t{:.6f}".format(train_loss))
    print("  validation loss:\t\t{:.6f}".format(val_loss))
    print("  training accuracy:\t\t{:.2f} %".format(train_accuracy * 100))
    print("  validation accuracy:\t\t{:.2f} %".format(val_accuracy * 100))
# Out:
# Epoch 1 of 120 time elapsed 31.703s
#   training loss:		2.196953
#   validation loss:		2.053815
#   training accuracy:		21.44 %
#   validation accuracy:		23.59 %
# Epoch 2 of 120 time elapsed 62.636s
#   training loss:		2.082692
#   validation loss:		2.034039
#   training accuracy:		21.59 %
#   validation accuracy:		23.67 %
# Epoch 3 of 120 time elapsed 94.903s
#   training loss:		2.060986
#   validation loss:		2.030998
#   training accuracy:		22.99 %
#   validation accuracy:		23.98 %
# Epoch 4 of 120 time elapsed 129.033s
#   training loss:		2.025746
#   validation loss:		1.915054
#   training accuracy:		27.32 %
#   validation accuracy:		33.67 %
# Epoch 5 of 120 time elapsed 161.069s
#   training loss:		1.918714
#   validation loss:		1.800555
#   training accuracy:		32.71 %
#   validation accuracy:		39.53 %
# Epoch 6 of 120 time elapsed 191.808s
#   training loss:		1.861157
#   validation loss:		1.738556
#   training accuracy:		34.27 %
#   validation accuracy:		41.09 %
# Epoch 7 of 120 time elapsed 223.320s
#   training loss:		1.816309
#   validation loss:		1.745395
#   training accuracy:		35.81 %
#   validation accuracy:		38.36 %
# Epoch 8 of 120 time elapsed 255.459s
#   training loss:		1.759214
#   validation loss:		1.774511
#   training accuracy:		39.25 %
#   validation accuracy:		38.36 %
# Epoch 9 of 120 time elapsed 285.946s
#   training loss:		1.732979
#   validation loss:		1.638430
#   training accuracy:		38.40 %
#   validation accuracy:		39.69 %
# Epoch 10 of 120 time elapsed 319.163s
#   training loss:		1.685600
#   validation loss:		1.676834
#   training accuracy:		40.67 %
#   validation accuracy:		39.45 %
# Epoch 11 of 120 time elapsed 350.578s
#   training loss:		1.636527
#   validation loss:		1.528588
#   training accuracy:		41.84 %
#   validation accuracy:		45.39 %
# Epoch 12 of 120 time elapsed 382.003s
#   training loss:		1.591840
#   validation loss:		1.644961
#   training accuracy:		44.24 %
#   validation accuracy:		44.22 %
# Epoch 13 of 120 time elapsed 413.393s
#   training loss:		1.564430
#   validation loss:		1.492318
#   training accuracy:		45.15 %
#   validation accuracy:		46.25 %
# Epoch 14 of 120 time elapsed 444.889s
#   training loss:		1.511708
#   validation loss:		1.368180
#   training accuracy:		46.67 %
#   validation accuracy:		51.09 %
# Epoch 15 of 120 time elapsed 476.482s
#   training loss:		1.430096
#   validation loss:		1.307130
#   training accuracy:		49.42 %
#   validation accuracy:		51.09 %
# Epoch 16 of 120 time elapsed 507.813s
#   training loss:		1.367783
#   validation loss:		1.245286
#   training accuracy:		49.47 %
#   validation accuracy:		51.33 %
# Epoch 17 of 120 time elapsed 538.516s
#   training loss:		1.312145
#   validation loss:		1.218439
#   training accuracy:		51.01 %
#   validation accuracy:		53.98 %
# Epoch 18 of 120 time elapsed 570.185s
#   training loss:		1.230885
#   validation loss:		1.075620
#   training accuracy:		54.71 %
#   validation accuracy:		59.38 %
# Epoch 19 of 120 time elapsed 601.983s
#   training loss:		1.144197
#   validation loss:		1.056375
#   training accuracy:		57.52 %
#   validation accuracy:		58.28 %
# Epoch 20 of 120 time elapsed 634.531s
#   training loss:		1.153833
#   validation loss:		1.057995
#   training accuracy:		56.91 %
#   validation accuracy:		59.30 %
# Epoch 21 of 120 time elapsed 666.100s
#   training loss:		1.065429
#   validation loss:		0.969080
#   training accuracy:		59.42 %
#   validation accuracy:		62.11 %
# Epoch 22 of 120 time elapsed 697.777s
#   training loss:		1.050730
#   validation loss:		1.003284
#   training accuracy:		60.07 %
#   validation accuracy:		59.53 %
# Epoch 23 of 120 time elapsed 729.855s
#   training loss:		1.020881
#   validation loss:		0.943977
#   training accuracy:		60.69 %
#   validation accuracy:		62.66 %
# Epoch 24 of 120 time elapsed 761.725s
#   training loss:		0.995558
#   validation loss:		0.968911
#   training accuracy:		61.53 %
#   validation accuracy:		60.70 %
# Epoch 25 of 120 time elapsed 793.047s
#   training loss:		0.975516
#   validation loss:		0.910482
#   training accuracy:		62.36 %
#   validation accuracy:		61.41 %
# Epoch 26 of 120 time elapsed 823.804s
#   training loss:		0.971777
#   validation loss:		0.917546
#   training accuracy:		62.40 %
#   validation accuracy:		62.27 %
# Epoch 27 of 120 time elapsed 855.611s
#   training loss:		0.970155
#   validation loss:		0.896906
#   training accuracy:		62.75 %
#   validation accuracy:		62.89 %
# Epoch 28 of 120 time elapsed 887.758s
#   training loss:		0.939205
#   validation loss:		0.893169
#   training accuracy:		63.10 %
#   validation accuracy:		62.11 %
# Epoch 29 of 120 time elapsed 918.536s
#   training loss:		0.950790
#   validation loss:		0.902192
#   training accuracy:		62.56 %
#   validation accuracy:		62.81 %
# Epoch 30 of 120 time elapsed 951.895s
#   training loss:		0.932593
#   validation loss:		0.880916
#   training accuracy:		62.95 %
#   validation accuracy:		63.20 %
# Epoch 31 of 120 time elapsed 982.160s
#   training loss:		0.900565
#   validation loss:		0.849895
#   training accuracy:		64.06 %
#   validation accuracy:		64.22 %
# Epoch 32 of 120 time elapsed 1012.654s
#   training loss:		0.918785
#   validation loss:		0.868219
#   training accuracy:		64.02 %
#   validation accuracy:		65.08 %
# Epoch 33 of 120 time elapsed 1044.259s
#   training loss:		0.903819
#   validation loss:		0.843417
#   training accuracy:		64.14 %
#   validation accuracy:		64.22 %
# Epoch 34 of 120 time elapsed 1074.774s
#   training loss:		0.877226
#   validation loss:		0.869771
#   training accuracy:		64.80 %
#   validation accuracy:		65.47 %
# Epoch 35 of 120 time elapsed 1105.781s
#   training loss:		0.864898
#   validation loss:		0.868068
#   training accuracy:		65.87 %
#   validation accuracy:		68.28 %
# Epoch 36 of 120 time elapsed 1136.381s
#   training loss:		0.888077
#   validation loss:		0.830028
#   training accuracy:		65.32 %
#   validation accuracy:		66.33 %
# Epoch 37 of 120 time elapsed 1167.902s
#   training loss:		0.850688
#   validation loss:		0.799315
#   training accuracy:		66.88 %
#   validation accuracy:		66.80 %
# Epoch 38 of 120 time elapsed 1200.506s
#   training loss:		0.831978
#   validation loss:		0.835571
#   training accuracy:		67.58 %
#   validation accuracy:		66.80 %
# Epoch 39 of 120 time elapsed 1233.435s
#   training loss:		0.824209
#   validation loss:		0.815451
#   training accuracy:		67.27 %
#   validation accuracy:		65.70 %
# Epoch 40 of 120 time elapsed 1264.864s
#   training loss:		0.804195
#   validation loss:		0.782271
#   training accuracy:		68.24 %
#   validation accuracy:		68.12 %
# Epoch 41 of 120 time elapsed 1297.553s
#   training loss:		0.794567
#   validation loss:		0.766895
#   training accuracy:		69.53 %
#   validation accuracy:		69.45 %
# Epoch 42 of 120 time elapsed 1329.339s
#   training loss:		0.801768
#   validation loss:		0.781531
#   training accuracy:		68.52 %
#   validation accuracy:		71.48 %
# Epoch 43 of 120 time elapsed 1361.136s
#   training loss:		0.792635
#   validation loss:		0.831502
#   training accuracy:		70.31 %
#   validation accuracy:		68.28 %
# Epoch 44 of 120 time elapsed 1393.183s
#   training loss:		0.807391
#   validation loss:		0.789537
#   training accuracy:		69.37 %
#   validation accuracy:		71.09 %
# Epoch 45 of 120 time elapsed 1425.119s
#   training loss:		0.772937
#   validation loss:		0.736658
#   training accuracy:		70.79 %
#   validation accuracy:		70.70 %
# Epoch 46 of 120 time elapsed 1458.770s
#   training loss:		0.758453
#   validation loss:		0.731825
#   training accuracy:		70.93 %
#   validation accuracy:		70.23 %
# Epoch 47 of 120 time elapsed 1491.345s
#   training loss:		0.753889
#   validation loss:		0.744839
#   training accuracy:		72.41 %
#   validation accuracy:		73.20 %
# Epoch 48 of 120 time elapsed 1522.851s
#   training loss:		0.765314
#   validation loss:		0.717085
#   training accuracy:		71.57 %
#   validation accuracy:		74.14 %
# Epoch 49 of 120 time elapsed 1554.047s
#   training loss:		0.730413
#   validation loss:		0.713947
#   training accuracy:		72.51 %
#   validation accuracy:		75.00 %
# Epoch 50 of 120 time elapsed 1586.029s
#   training loss:		0.718972
#   validation loss:		0.729734
#   training accuracy:		73.36 %
#   validation accuracy:		74.30 %
# Epoch 51 of 120 time elapsed 1622.453s
#   training loss:		0.720188
#   validation loss:		0.738495
#   training accuracy:		73.29 %
#   validation accuracy:		72.58 %
# Epoch 52 of 120 time elapsed 1656.809s
#   training loss:		0.712220
#   validation loss:		0.740466
#   training accuracy:		72.76 %
#   validation accuracy:		70.00 %
# Epoch 53 of 120 time elapsed 1691.266s
#   training loss:		0.698332
#   validation loss:		0.711137
#   training accuracy:		73.25 %
#   validation accuracy:		75.23 %
# Epoch 54 of 120 time elapsed 1723.851s
#   training loss:		0.702309
#   validation loss:		0.706982
#   training accuracy:		73.87 %
#   validation accuracy:		75.55 %
# Epoch 55 of 120 time elapsed 1756.123s
#   training loss:		0.686110
#   validation loss:		0.712825
#   training accuracy:		74.44 %
#   validation accuracy:		73.52 %
# Epoch 56 of 120 time elapsed 1789.841s
#   training loss:		0.681945
#   validation loss:		0.789234
#   training accuracy:		74.24 %
#   validation accuracy:		71.88 %
# Epoch 57 of 120 time elapsed 1821.845s
#   training loss:		0.688000
#   validation loss:		0.712905
#   training accuracy:		74.32 %
#   validation accuracy:		75.55 %
# Epoch 58 of 120 time elapsed 1852.792s
#   training loss:		0.668737
#   validation loss:		0.772034
#   training accuracy:		75.33 %
#   validation accuracy:		74.38 %
# Epoch 59 of 120 time elapsed 1883.315s
#   training loss:		0.668940
#   validation loss:		0.696823
#   training accuracy:		75.80 %
#   validation accuracy:		76.64 %
# Epoch 60 of 120 time elapsed 1914.261s
#   training loss:		0.672090
#   validation loss:		0.741194
#   training accuracy:		75.33 %
#   validation accuracy:		74.45 %
# Epoch 61 of 120 time elapsed 1945.850s
#   training loss:		0.657398
#   validation loss:		0.679934
#   training accuracy:		75.49 %
#   validation accuracy:		76.88 %
# Epoch 62 of 120 time elapsed 1976.773s
#   training loss:		0.668244
#   validation loss:		0.674577
#   training accuracy:		75.72 %
#   validation accuracy:		76.02 %
# Epoch 63 of 120 time elapsed 2008.307s
#   training loss:		0.654042
#   validation loss:		0.667069
#   training accuracy:		75.78 %
#   validation accuracy:		76.48 %
# Epoch 64 of 120 time elapsed 2039.530s
#   training loss:		0.610784
#   validation loss:		0.708390
#   training accuracy:		76.56 %
#   validation accuracy:		75.62 %
# Epoch 65 of 120 time elapsed 2070.610s
#   training loss:		0.624127
#   validation loss:		0.666718
#   training accuracy:		76.25 %
#   validation accuracy:		77.11 %
# Epoch 66 of 120 time elapsed 2103.160s
#   training loss:		0.616227
#   validation loss:		0.668960
#   training accuracy:		76.95 %
#   validation accuracy:		76.33 %
# Epoch 67 of 120 time elapsed 2134.045s
#   training loss:		0.640048
#   validation loss:		0.696513
#   training accuracy:		76.03 %
#   validation accuracy:		76.80 %
# Epoch 68 of 120 time elapsed 2165.965s
#   training loss:		0.655739
#   validation loss:		0.738331
#   training accuracy:		76.42 %
#   validation accuracy:		76.41 %
# Epoch 69 of 120 time elapsed 2197.814s
#   training loss:		0.603237
#   validation loss:		0.739690
#   training accuracy:		77.41 %
#   validation accuracy:		75.16 %
# Epoch 70 of 120 time elapsed 2229.516s
#   training loss:		0.616037
#   validation loss:		0.675809
#   training accuracy:		77.24 %
#   validation accuracy:		77.66 %
# Epoch 71 of 120 time elapsed 2262.314s
#   training loss:		0.599136
#   validation loss:		0.734719
#   training accuracy:		77.88 %
#   validation accuracy:		75.47 %
# Epoch 72 of 120 time elapsed 2296.344s
#   training loss:		0.612327
#   validation loss:		0.686628
#   training accuracy:		77.73 %
#   validation accuracy:		76.09 %
# Epoch 73 of 120 time elapsed 2329.361s
#   training loss:		0.627552
#   validation loss:		0.684230
#   training accuracy:		76.54 %
#   validation accuracy:		77.58 %
# Epoch 74 of 120 time elapsed 2361.262s
#   training loss:		0.592307
#   validation loss:		0.696590
#   training accuracy:		77.71 %
#   validation accuracy:		77.50 %
# Epoch 75 of 120 time elapsed 2393.162s
#   training loss:		0.584676
#   validation loss:		0.707685
#   training accuracy:		78.37 %
#   validation accuracy:		77.81 %
# Epoch 76 of 120 time elapsed 2427.871s
#   training loss:		0.574824
#   validation loss:		0.722486
#   training accuracy:		78.17 %
#   validation accuracy:		77.19 %
# Epoch 77 of 120 time elapsed 2459.650s
#   training loss:		0.567967
#   validation loss:		0.675065
#   training accuracy:		78.66 %
#   validation accuracy:		78.12 %
# Epoch 78 of 120 time elapsed 2491.778s
#   training loss:		0.566399
#   validation loss:		0.671791
#   training accuracy:		78.66 %
#   validation accuracy:		77.27 %
# Epoch 79 of 120 time elapsed 2522.915s
#   training loss:		0.567182
#   validation loss:		0.699287
#   training accuracy:		78.78 %
#   validation accuracy:		77.42 %
# Epoch 80 of 120 time elapsed 2554.255s
#   training loss:		0.574655
#   validation loss:		0.640787
#   training accuracy:		78.47 %
#   validation accuracy:		78.36 %
# Epoch 81 of 120 time elapsed 2585.631s
#   training loss:		0.546169
#   validation loss:		0.675525
#   training accuracy:		79.34 %
#   validation accuracy:		77.42 %
# Epoch 82 of 120 time elapsed 2617.109s
#   training loss:		0.538847
#   validation loss:		0.709854
#   training accuracy:		78.91 %
#   validation accuracy:		78.05 %
# Epoch 83 of 120 time elapsed 2649.000s
#   training loss:		0.564395
#   validation loss:		0.710110
#   training accuracy:		79.85 %
#   validation accuracy:		78.12 %
# Epoch 84 of 120 time elapsed 2680.527s
#   training loss:		0.542757
#   validation loss:		0.697959
#   training accuracy:		79.87 %
#   validation accuracy:		77.11 %
# Epoch 85 of 120 time elapsed 2711.440s
#   training loss:		0.550730
#   validation loss:		0.711990
#   training accuracy:		79.77 %
#   validation accuracy:		77.34 %
# Epoch 86 of 120 time elapsed 2742.366s
#   training loss:		0.574851
#   validation loss:		0.682433
#   training accuracy:		77.78 %
#   validation accuracy:		77.81 %
# Epoch 87 of 120 time elapsed 2773.416s
#   training loss:		0.546648
#   validation loss:		0.682860
#   training accuracy:		79.48 %
#   validation accuracy:		78.28 %
# Epoch 88 of 120 time elapsed 2804.641s
#   training loss:		0.543190
#   validation loss:		0.679394
#   training accuracy:		80.00 %
#   validation accuracy:		77.81 %
# Epoch 89 of 120 time elapsed 2836.230s
#   training loss:		0.536462
#   validation loss:		0.749098
#   training accuracy:		80.14 %
#   validation accuracy:		77.89 %
# Epoch 90 of 120 time elapsed 2867.100s
#   training loss:		0.523493
#   validation loss:		0.674118
#   training accuracy:		80.76 %
#   validation accuracy:		79.14 %
# Epoch 91 of 120 time elapsed 2897.584s
#   training loss:		0.525502
#   validation loss:		0.684915
#   training accuracy:		80.02 %
#   validation accuracy:		79.14 %
# Epoch 92 of 120 time elapsed 2928.095s
#   training loss:		0.514359
#   validation loss:		0.684530
#   training accuracy:		80.96 %
#   validation accuracy:		78.20 %
# Epoch 93 of 120 time elapsed 2958.619s
#   training loss:		0.534406
#   validation loss:		0.754823
#   training accuracy:		80.37 %
#   validation accuracy:		77.73 %
# Epoch 94 of 120 time elapsed 2989.091s
#   training loss:		0.515920
#   validation loss:		0.701268
#   training accuracy:		80.39 %
#   validation accuracy:		78.98 %
# Epoch 95 of 120 time elapsed 3019.659s
#   training loss:		0.546750
#   validation loss:		0.678417
#   training accuracy:		79.85 %
#   validation accuracy:		78.91 %
# Epoch 96 of 120 time elapsed 3050.078s
#   training loss:		0.509965
#   validation loss:		0.741114
#   training accuracy:		80.88 %
#   validation accuracy:		76.95 %
# Epoch 97 of 120 time elapsed 3080.497s
#   training loss:		0.533009
#   validation loss:		0.710076
#   training accuracy:		80.74 %
#   validation accuracy:		78.75 %
# Epoch 98 of 120 time elapsed 3112.637s
#   training loss:		0.514252
#   validation loss:		0.642227
#   training accuracy:		80.82 %
#   validation accuracy:		79.53 %
# Epoch 99 of 120 time elapsed 3146.357s
#   training loss:		0.476900
#   validation loss:		0.670738
#   training accuracy:		81.72 %
#   validation accuracy:		79.53 %
# Epoch 100 of 120 time elapsed 3178.337s
#   training loss:		0.499227
#   validation loss:		0.647647
#   training accuracy:		81.52 %
#   validation accuracy:		79.77 %
# Epoch 101 of 120 time elapsed 3209.796s
#   training loss:		0.491625
#   validation loss:		0.717002
#   training accuracy:		81.58 %
#   validation accuracy:		78.59 %
# Epoch 102 of 120 time elapsed 3240.103s
#   training loss:		0.496135
#   validation loss:		0.720395
#   training accuracy:		81.21 %
#   validation accuracy:		78.36 %
# Epoch 103 of 120 time elapsed 3271.383s
#   training loss:		0.484801
#   validation loss:		0.674567
#   training accuracy:		81.72 %
#   validation accuracy:		79.45 %
# Epoch 104 of 120 time elapsed 3303.180s
#   training loss:		0.490886
#   validation loss:		0.672368
#   training accuracy:		81.52 %
#   validation accuracy:		79.14 %
# Epoch 105 of 120 time elapsed 3339.635s
#   training loss:		0.537936
#   validation loss:		0.650079
#   training accuracy:		81.52 %
#   validation accuracy:		79.22 %
# Epoch 106 of 120 time elapsed 3371.849s
#   training loss:		0.470547
#   validation loss:		0.697368
#   training accuracy:		82.50 %
#   validation accuracy:		79.14 %
# Epoch 107 of 120 time elapsed 3403.730s
#   training loss:		0.471830
#   validation loss:		0.670866
#   training accuracy:		82.46 %
#   validation accuracy:		79.61 %
# Epoch 108 of 120 time elapsed 3434.409s
#   training loss:		0.485125
#   validation loss:		0.661751
#   training accuracy:		81.60 %
#   validation accuracy:		80.62 %
# Epoch 109 of 120 time elapsed 3465.149s
#   training loss:		0.491024
#   validation loss:		0.780899
#   training accuracy:		81.83 %
#   validation accuracy:		78.75 %
# Epoch 110 of 120 time elapsed 3496.070s
#   training loss:		0.495329
#   validation loss:		0.700005
#   training accuracy:		81.78 %
#   validation accuracy:		79.61 %
# Epoch 111 of 120 time elapsed 3526.861s
#   training loss:		0.481973
#   validation loss:		0.856541
#   training accuracy:		81.89 %
#   validation accuracy:		78.05 %
# Epoch 112 of 120 time elapsed 3558.466s
#   training loss:		0.489686
#   validation loss:		0.711232
#   training accuracy:		81.93 %
#   validation accuracy:		79.14 %
# Epoch 113 of 120 time elapsed 3593.657s
#   training loss:		0.465004
#   validation loss:		0.673239
#   training accuracy:		82.24 %
#   validation accuracy:		79.61 %
# Epoch 114 of 120 time elapsed 3627.756s
#   training loss:		0.483130
#   validation loss:		0.639298
#   training accuracy:		82.18 %
#   validation accuracy:		80.00 %
# Epoch 115 of 120 time elapsed 3659.529s
#   training loss:		0.447499
#   validation loss:		0.712631
#   training accuracy:		83.33 %
#   validation accuracy:		80.47 %
# Epoch 116 of 120 time elapsed 3690.776s
#   training loss:		0.450904
#   validation loss:		0.683523
#   training accuracy:		82.65 %
#   validation accuracy:		80.39 %
# Epoch 117 of 120 time elapsed 3721.393s
#   training loss:		0.442338
#   validation loss:		0.706409
#   training accuracy:		83.39 %
#   validation accuracy:		78.91 %
# Epoch 118 of 120 time elapsed 3752.816s
#   training loss:		0.446283
#   validation loss:		0.713899
#   training accuracy:		83.66 %
#   validation accuracy:		79.61 %
# Epoch 119 of 120 time elapsed 3783.475s
#   training loss:		0.484385
#   validation loss:		0.715563
#   training accuracy:		82.59 %
#   validation accuracy:		79.38 %
# Epoch 120 of 120 time elapsed 3813.817s
#   training loss:		0.464332
#   validation loss:		0.779812
#   training accuracy:		82.94 %
#   validation accuracy:		79.53 %

# %%
print("Minimum validation loss: {:.6f}".format(min_val_loss))
# Out:
# Minimum validation loss: 0.639298

# %% [markdown]
# ### Model loss and accuracy
# Here we plot the loss and the accuracy for the training and validation set at each epoch.

# %%
x_axis = range(num_epochs)
plt.figure(figsize=(8,6))
plt.plot(x_axis,loss_training)
plt.plot(x_axis,loss_validation)
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.legend(('Training','Validation'))

# %%
plt.figure(figsize=(8,6))
plt.plot(x_axis,acc_training)
plt.plot(x_axis,acc_validation)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(('Training','Validation'))

# %% [markdown]
# ### Confusion matrix
# The confusion matrix allows us to visualize how well is predicted each class and which are the most common misclassifications.

# %%
# Plot confusion matrix 
# Code based on http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

plt.figure(figsize=(8,8))
cmap=plt.cm.Blues   
plt.imshow(cf_val, interpolation='nearest', cmap=cmap)
plt.title('Confusion matrix validation set')
plt.colorbar()
tick_marks = np.arange(n_class)
classes = ['Nucleus','Cytoplasm','Extracellular','Mitochondrion','Cell membrane','ER',
           'Chloroplast','Golgi apparatus','Lysosome','Vacuole']

plt.xticks(tick_marks, classes, rotation=60)
plt.yticks(tick_marks, classes)

thresh = cf_val.max() / 2.
for i, j in itertools.product(range(cf_val.shape[0]), range(cf_val.shape[1])):
    plt.text(j, i, cf_val[i, j],
             horizontalalignment="center",
             color="white" if cf_val[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True location')
plt.xlabel('Predicted location');

# %% [markdown]
# ### Sequence attention
# Here we plot the attention values for the last validation batch. We can see that the attention differs between the subcellular localizations. The most clear examples are the extracellular proteins, where the attention is at the N-terminal, where the signal peptide is located.

# %%
sort_ind = np.argsort(targets)
alphas_1 = alphas[:,1,:][sort_ind]
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,15))
labels_plot = ax1.imshow(targets[sort_ind].reshape(128,1),cmap=plt.get_cmap('Set1'))
ax1.set_aspect(0.3)
ax1.set_axis_off()
cb = plt.colorbar(labels_plot)
labels = np.arange(0,10,1)
loc = labels + .5
cb.set_ticks(loc)
cb.set_ticklabels(classes)
att_plot = ax2.imshow(alphas_1, aspect='auto')
ax2.yaxis.set_visible(False)
plt.tight_layout(pad=25, w_pad=0.5, h_pad=1.0)
